# %%
#Import Libraries
import pandas as pd
import matplotlib.pyplot as plt

#Load Data
df = pd.read_csv("road_accident_statistics.csv")

#View Basic Dataset Info
print("🔹 Dataset Shape:", df.shape)
print("\n🔹 Columns:", df.columns.tolist())
print("\n🔹 Missing Values:\n", df.isnull().sum())
print("\n🔹 Data Types:\n", df.dtypes)

#Summary Statistics
print("\n🔹 Summary Statistics:\n", df.describe())

#Correlation Matrix
print("\n🔹 Correlation Matrix:\n", df.corr(numeric_only=True))
# Out:
# 🔹 Dataset Shape: (44, 7)
#
# 🔹 Columns: ['Year', 'Number of Accidents', 'Death', 'Number of Serious Injuries', 'Number of Minor Injuries', 'Number of Moderate Injuries', 'Number of Severe Injuries']
#
# 🔹 Missing Values:
#  Year                           0
# Number of Accidents            0
# Death                          0
# Number of Serious Injuries     0
# Number of Minor Injuries       0
# Number of Moderate Injuries    0
# Number of Severe Injuries      0
# dtype: int64
#
# 🔹 Data Types:
#  Year                           int64
# Number of Accidents            int64
# Death                          int64
# Number of Serious Injuries     int64
# Number of Minor Injuries       int64
# Number of Moderate Injuries    int64
# Number of Severe Injuries      int64
# dtype: object
#
# 🔹 Summary Statistics:
#                Year  Number of Accidents        Death  \
# count    44.000000            44.000000    44.000000
# mean   2001.500000           772.727273   613.636364
# ...

# %%
# Line plot for total accidents and deaths
plt.figure(figsize=(10, 6))
plt.plot(df['Year'], df['Number of Accidents'], label='Accidents', linewidth=2)
plt.plot(df['Year'], df['Death'], label='Deaths', linewidth=2, linestyle='--')
plt.title('Trend of Accidents and Deaths Over the Years')
plt.xlabel('Year')
plt.ylabel('Count')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Line plot for all injury types
plt.figure(figsize=(10, 6))
plt.plot(df['Year'], df['Number of Serious Injuries'], label='Serious Injuries')
plt.plot(df['Year'], df['Number of Minor Injuries'], label='Minor Injuries')
plt.plot(df['Year'], df['Number of Moderate Injuries'], label='Moderate Injuries')
plt.plot(df['Year'], df['Number of Severe Injuries'], label='Severe Injuries')
plt.title('Injury Trends Over the Years')
plt.xlabel('Year')
plt.ylabel('Injury Count')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Prepare data for stacked bar chart
injury_df = df[['Year', 'Number of Serious Injuries', 'Number of Minor Injuries',
                'Number of Moderate Injuries', 'Number of Severe Injuries']]
injury_df.set_index('Year', inplace=True)

# Plot stacked bar chart
injury_df.plot(kind='bar', stacked=True, figsize=(14, 7))
plt.title('Year-wise Injury Severity Distribution')
plt.xlabel('Year')
plt.ylabel('Total Injuries')
plt.tight_layout()
plt.show()

# %%
# Find year with most accidents and deaths
max_accidents = df[df['Number of Accidents'] == df['Number of Accidents'].max()]
min_accidents = df[df['Number of Accidents'] == df['Number of Accidents'].min()]

max_deaths = df[df['Death'] == df['Death'].max()]
min_deaths = df[df['Death'] == df['Death'].min()]

print("\n🔺 Year with Maximum Accidents:\n", max_accidents)
print("\n🔻 Year with Minimum Accidents:\n", min_accidents)
print("\n💀 Year with Maximum Deaths:\n", max_deaths)
print("\n😇 Year with Minimum Deaths:\n", min_deaths)
# Out:
# 🔺 Year with Maximum Accidents:
#     Year  Number of Accidents  Death  Number of Serious Injuries  \
# 0  1980                 1500   1300                        1200
#
#    Number of Minor Injuries  Number of Moderate Injuries  \
# 0                       400                          200
#
#    Number of Severe Injuries
# 0                        100
#
# 🔻 Year with Minimum Accidents:
#      Year  Number of Accidents  Death  Number of Serious Injuries  \
# 26  2006                  200    100                          50
#
#     Number of Minor Injuries  Number of Moderate Injuries  \
# 26                         3                            1
#
#     Number of Severe Injuries
# 26                          0
#
# 💀 Year with Maximum Deaths:
#     Year  Number of Accidents  Death  Number of Serious Injuries  \
# 0  1980                 1500   1300                        1200
#
#    Number of Minor Injuries  Number of Moderate Injuries  \
# ...

# %%
#Import libraries
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

#Load your dataset
df = pd.read_csv("road_accident_statistics.csv")

#Select features and target
X = df[['Year']]  # Feature
y = df['Number of Accidents']  # Target

#Train the Linear Regression model
model = LinearRegression()
model.fit(X, y)

#Predict on training data
y_pred = model.predict(X)

#Evaluate the model
print("📉 Mean Squared Error:", mean_squared_error(y, y_pred))
print("📈 R² Score:", r2_score(y, y_pred))

#Plot actual vs predicted
plt.figure(figsize=(10, 6))
plt.scatter(X, y, color='blue', label='Actual Data')
plt.plot(X, y_pred, color='red', linewidth=2, label='Predicted Trend')
plt.title("Accident Prediction using Linear Regression")
plt.xlabel("Year")
plt.ylabel("Number of Accidents")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# 📉 Mean Squared Error: 88784.40322890652
# 📈 R² Score: 0.2938681922144316

# %%
# Predict for future years (2024 to 2030)
future_years = pd.DataFrame({'Year': list(range(2024, 2031))})
future_predictions = model.predict(future_years)

# Display future predictions
print("\n🔮 Predicted Accidents for Future Years:")
for year, prediction in zip(future_years['Year'], future_predictions):
    print(f"{year}: {int(prediction)} accidents")
# Out:
# 🔮 Predicted Accidents for Future Years:
# 2024: 432 accidents
# 2025: 416 accidents
# 2026: 401 accidents
# 2027: 386 accidents
# 2028: 371 accidents
# 2029: 356 accidents
# 2030: 341 accidents
